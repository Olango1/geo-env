# %%
#Importing the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc
import sys
import xarray as xr
import pandas as pd

#open the files
discharge_main= pd.read_csv('output10_1/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_precn025= pd.read_csv('output10_precn025/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_precp025= pd.read_csv('output10_precp025/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tavgn025= pd.read_csv('output10_tavgn025/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tavgp025= pd.read_csv('output10_tavgp025/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tmelt15= pd.read_csv('output10_tmelt15/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tsnow15= pd.read_csv('output10_tsnow15/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tmelt5= pd.read_csv('output10_tmelt5/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
discharge_tsnow5= pd.read_csv('output10_tsnow5/discharge_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
# discharge_annual=xr.open_dataset('discharge_annualtot.nc', decode_times=False)
# runoff= xr.open_dataset('runoff_annualtot.nc', decode_times=False)
# totalet= xr.open_dataset('totalET_annualtot.nc', decode_times=False)
# precipitation= xr.open_dataset('Precipitation_annualtot.nc', decode_times=False)

#Open files for evapotranspiration
evap_main= pd.read_csv('output10_1/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_precn025= pd.read_csv('output10_precn025/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_precp025= pd.read_csv('output10_precp025/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tavgn025= pd.read_csv('output10_tavgn025/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tavgp025= pd.read_csv('output10_tavgp025/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tmelt15= pd.read_csv('output10_tmelt15/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tsnow15= pd.read_csv('output10_tsnow15/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tmelt5= pd.read_csv('output10_tmelt5/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)
evap_tsnow5= pd.read_csv('output10_tsnow5/totalET_daily.tss', delimiter=r'\s+', skiprows=5,header=None)

#open files for runoff
runoff_main= xr.open_dataset('output10_1/runoff_monthavg.nc', decode_times=False)
runoff_precn025= xr.open_dataset('output10_precn025/runoff_monthavg.nc', decode_times=False)
runoff_precp025= xr.open_dataset('output10_precp025/runoff_monthavg.nc', decode_times=False)
runoff_tavgn025= xr.open_dataset('output10_tavgn025/runoff_monthavg.nc', decode_times=False)
runoff_tavgp025= xr.open_dataset('output10_tavgp025/runoff_monthavg.nc', decode_times=False)
runoff_tmelt15= xr.open_dataset('output10_tmelt15/runoff_monthavg.nc', decode_times=False)
runoff_tsnow15= xr.open_dataset('output10_tsnow15/runoff_monthavg.nc', decode_times=False)
runoff_tmelt5= xr.open_dataset('output10_tmelt5/runoff_monthavg.nc', decode_times=False)
runoff_tsnow5= xr.open_dataset('output10_tsnow5/runoff_monthavg.nc', decode_times=False)



print(discharge_main)
# Out:
#          0        1        2
# 0     4018  3052.28  236.735
# 1     4019  4604.96  236.506
# 2     4020  6015.84  219.507
# 3     4021  6345.12  197.477
# 4     4022  5872.02  176.542
# ...    ...      ...      ...
# 3648  7666  3676.76  192.977
# 3649  7667  3411.03  167.384
# 3650  7668  3242.80  157.929
# 3651  7669  3099.29  141.854
# 3652  7670  3074.81  155.881
#
# [3653 rows x 3 columns]

# %%
#create new dataframe with second column from all the imported dataframes to compare precipitation
df_prec = pd.DataFrame()
df_prec['precipitation at 1.0'] = discharge_main[1]
df_prec['precipitation at 0.6'] = discharge_precn025[1]
df_prec['precipitation at 1.4'] = discharge_precp025[1]
df_prec['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_prec.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_prec.plot()
plt.title('Discharge data-Precipitation')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()

#plot the discharge plot zooming into the last 6 months
plt.figure(figsize=(20,10))
df_prec[-180:].plot()
plt.title('Discharge data for the last 6 months -Precipitation')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/996712487.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_prec['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#create new dataframe with second column from all the imported dataframes to compare temperature
df_tavg = pd.DataFrame()
df_tavg['temperature at 1.0'] = discharge_main[1]
df_tavg['temperature at 0.6'] = discharge_tavgn025[1]
df_tavg['temperature at 1.4'] = discharge_tavgp025[1]
df_tavg['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_tavg.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_tavg.plot()
plt.title('Discharge data-Temperature')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()

#plot the discharge plot zooming into the last 6 months
plt.figure(figsize=(20,10))
df_tavg[-180:].plot()
plt.title('Discharge data for the last 6 months-Temperature')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/1814732646.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_tavg['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#Factors influencing precipitation and snow

df_TempSnow = pd.DataFrame()
df_TempSnow['TempSnow at 1.0'] = discharge_main[1]
df_TempSnow['TempSnow at 1.5'] = discharge_tsnow15[1]
df_TempSnow['TempSnow at 5.0'] = discharge_tsnow5[1]
df_TempSnow['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_TempSnow.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_TempSnow.plot()
plt.title('Discharge data-TempSnow')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()

#plot the discharge plot zooming into the last 6 months
plt.figure(figsize=(20,10))
df_TempSnow[-360:].plot()
plt.title('Discharge data for the last 1 year-TempSnow')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/1944434198.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_TempSnow['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#Factors influencing precipitation and snow

df_TempMelt = pd.DataFrame()
df_TempMelt['TempMelt at 1.0'] = discharge_main[1]
df_TempMelt['TempMelt at 1.5'] = discharge_tmelt15[1]
df_TempMelt['TempMelt at 5.0'] = discharge_tmelt5[1]
df_TempMelt['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_TempMelt.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_TempMelt.plot()
plt.title('Discharge data-TempSnow')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()

#plot the discharge plot zooming into the last 6 months
plt.figure(figsize=(20,10))
df_TempMelt[-360:].plot()
plt.title('Discharge data for the last 1 year-TempSnow')
plt.xlabel('Date')
plt.ylabel('Discharge (cm3/s)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/1433720615.py:7: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_TempMelt['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#create new dataframe with second column from all the imported dataframes to compare evapotranspiration and do plots
df_evap = pd.DataFrame()
df_evap['evapotranspiration at 1.0'] = evap_main[1]
df_evap['evapotranspiration at 0.6'] = evap_precn025[1]
df_evap['evapotranspiration at 1.4'] = evap_precp025[1]
df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_evap.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_evap.plot()
plt.title('Evapotranspiration data')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()

#plot the discharge plot zooming into the last 1 months
plt.figure(figsize=(20,10))
df_evap[-360:].plot()
plt.title('Evapotranspiration data for the last 1 year')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/4025606289.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#create new dataframe with second column from all the imported dataframes to compare evapotranspiration and do plots based on temperature
df_evap = pd.DataFrame()
df_evap['evapotranspiration at 1.0'] = evap_main[1]
df_evap['evapotranspiration at 0.6'] = evap_tavgn025[1]
df_evap['evapotranspiration at 1.4'] = evap_tavgp025[1]
df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_evap.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_evap.plot()
plt.title('Evapotranspiration data')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()

#plot the discharge plot zooming into the last 1 year
plt.figure(figsize=(20,10))
df_evap[-90:].plot()
plt.title('Evapotranspiration data for the last 1 year')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/350322186.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#create new dataframe with second column from all the imported dataframes to compare evapotranspiration and do plots based on TempSnow
df_evap = pd.DataFrame()
df_evap['evapotranspiration at 1.0'] = evap_main[1]
df_evap['evapotranspiration at 1.5'] = evap_tsnow15[1]
df_evap['evapotranspiration at 5.0'] = evap_tsnow5[1]
df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_evap.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_evap.plot()
plt.title('Evapotranspiration data')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()

#plot the discharge plot zooming into the last 1 year
plt.figure(figsize=(20,10))
df_evap[-360:].plot()
plt.title('Evapotranspiration data for the last 1 year')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()

#create new dataframe with second column from all the imported dataframes to compare evapotranspiration and do plots based on TempMelt
df_evap = pd.DataFrame()
df_evap['evapotranspiration at 1.0'] = evap_main[1]
df_evap['evapotranspiration at 1.5'] = evap_tmelt15[1]
df_evap['evapotranspiration at 5.0'] = evap_tmelt5[1]
df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
df_evap.set_index('date', inplace=True)

#plot the discharge data in one plot
plt.figure(figsize=(20,10))
df_evap.plot()
plt.title('Evapotranspiration data')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()

#plot the discharge plot zooming into the last 1 year
plt.figure(figsize=(20,10))
df_evap[-360:].plot()
plt.title('Evapotranspiration data for the last 1 year')
plt.xlabel('Date')
plt.ylabel('Evapotranspiration (m)')
plt.show()
# Out:
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/2289729263.py:6: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')
# /var/folders/kw/2jv6j2954mz4lzk_ptf0p3z8bh_7ct/T/ipykernel_14787/2289729263.py:30: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df_evap['date']=pd.date_range(start='31/12/2001', periods=len(discharge_main), freq='D')

# %%
#Calculate the total change in discharge for each of the factors using discharge 1.0 as the base for discharge at 0.6 and 1.4 separately
prec_change_06= (discharge_precn025[1].sum()/discharge_main[1].sum())*100
prec_change_14= (discharge_precp025[1].sum()/discharge_main[1].sum())*100
temp_change_06= (discharge_tavgn025[1].sum()/discharge_main[1].sum())*100
temp_change_14= (discharge_tavgp025[1].sum()/discharge_main[1].sum())*100


#For TempSnow and TempMelt
snow_change_15= (discharge_tsnow15[1].sum()/discharge_main[1].sum())*100
snow_change_5= (discharge_tsnow5[1].sum()/discharge_main[1].sum())*100
melt_change_15= (discharge_tmelt15[1].sum()/discharge_main[1].sum())*100
melt_change_5= (discharge_tmelt5[1].sum()/discharge_main[1].sum())*100

#For evapotranspiration
evap_change_06= (evap_precn025[1].sum()/evap_main[1].sum())*100
evap_change_14= (evap_precp025[1].sum()/evap_main[1].sum())*100
evap_change_06= (evap_tavgn025[1].sum()/evap_main[1].sum())*100
evap_change_14= (evap_tavgp025[1].sum()/evap_main[1].sum())*100
evap_change_15= (evap_tsnow15[1].sum()/evap_main[1].sum())*100
evap_change_5= (evap_tsnow5[1].sum()/evap_main[1].sum())*100
evap_change_15= (evap_tmelt15[1].sum()/evap_main[1].sum())*100
evap_change_5= (evap_tmelt5[1].sum()/evap_main[1].sum())*100

#Print the results
print('The change in discharge due to precipitation at 0.6 is:', prec_change_06)
print('The change in discharge due to precipitation at 1.4 is:', prec_change_14)
print('The change in discharge due to temperature at 0.6 is:', temp_change_06)
print('The change in discharge due to temperature at 1.4 is:', temp_change_14)
print('The change in discharge due to TempSnow at 1.5 is:', snow_change_15)
print('The change in discharge due to TempSnow at 5.0 is:', snow_change_5)
print('The change in discharge due to TempMelt at 1.5 is:', melt_change_15)
print('The change in discharge due to TempMelt at 5.0 is:', melt_change_5)
print('The change in discharge due to evapotranspiration at 0.6 is:', evap_change_06)
print('The change in discharge due to evapotranspiration at 1.4 is:', evap_change_14)
print('The change in discharge due to evapotranspiration at 1.5 is:', evap_change_15)
print('The change in discharge due to evapotranspiration at 5.0 is:', evap_change_5)
print('The change in discharge due to evapotranspiration at 1.5 is:', evap_change_15)
print('The change in discharge due to evapotranspiration at 5.0 is:', evap_change_5)
print('The change in discharge due to evapotranspiration at 1.5 is:', evap_change_15)
print('The change in discharge due to evapotranspiration at 5.0 is:', evap_change_5)
# Out:
# The change in discharge due to precipitation at 0.6 is: 33.46332342789422
# The change in discharge due to precipitation at 1.4 is: 181.8789570099563
# The change in discharge due to temperature at 0.6 is: 98.02253336687603
# The change in discharge due to temperature at 1.4 is: 101.04106022786215
# The change in discharge due to TempSnow at 1.5 is: 99.87416155983277
# The change in discharge due to TempSnow at 5.0 is: 98.5925629359157
# The change in discharge due to TempMelt at 1.5 is: 99.93512006008426
# The change in discharge due to TempMelt at 5.0 is: 99.17776943110718
# The change in discharge due to evapotranspiration at 0.6 is: 100.07777184035224
# The change in discharge due to evapotranspiration at 1.4 is: 99.9338634134909
# The change in discharge due to evapotranspiration at 1.5 is: 99.99194943976012
# The change in discharge due to evapotranspiration at 5.0 is: 100.06027505912327
# The change in discharge due to evapotranspiration at 1.5 is: 99.99194943976012
# ...

# %%
#Get lat and lon from the runoff xarray
run_lat = runoff_main['lat'].values
run_lon = runoff_main['lon'].values
#Get the runoff data for each factor
run_main=runoff_main['runoff_monthavg']
run_precn025=runoff_precn025['runoff_monthavg']
run_precp025=runoff_precp025['runoff_monthavg']
run_tavgn025=runoff_tavgn025['runoff_monthavg']
run_tavgp025=runoff_tavgp025['runoff_monthavg']
run_tmelt15=runoff_tmelt15['runoff_monthavg']
run_tsnow15=runoff_tsnow15['runoff_monthavg']
run_tmelt5=runoff_tmelt5['runoff_monthavg']
run_tsnow5=runoff_tsnow5['runoff_monthavg']

#get the average runoff for each factor as they are monthly data for 10 years tsnow and melt

# %%
run_main_avg=run_main.mean()
run_precn025_avg=run_precn025.mean()
run_precp025_avg=run_precp025.mean()
run_tavgn025_avg=run_tavgn025.mean()
run_tavgp025_avg=run_tavgp025.mean()
run_tmelt15_avg=run_tmelt15.mean()
run_tsnow15_avg=run_tsnow15.mean()
run_tmelt5_avg=run_tmelt5.mean()
run_tsnow5_avg=run_tsnow5.mean()

# %%
#for each grid cell, calculate the percentage change in average runoff for each factor with respect to the base as 1.0 the the whole data not just the first month
run_main=run_main.mean(dim='time')

run_precn025=run_precn025.mean(dim='time')
run_precp025=run_precp025.mean(dim='time')
run_tavgn025=run_tavgn025.mean(dim='time')
run_tavgp025=run_tavgp025.mean(dim='time')
run_tmelt15=run_tmelt15.mean(dim='time')
run_tsnow15=run_tsnow15.mean(dim='time')
run_tmelt5=run_tmelt5.mean(dim='time')
run_tsnow5=run_tsnow5.mean(dim='time')

#plot map of the percentage change in average runoff for each factor with respect to the base as 1.0
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolor(run_lon, run_lat, (run_precn025/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to precipitation at 0.6')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1,2,2)
plt.pcolor(run_lon, run_lat, (run_precp025/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to precipitation at 1.4')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#for temperature
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolor(run_lon, run_lat, (run_tavgn025/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to temperature at 0.6')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1,2,2)
plt.pcolor(run_lon, run_lat, (run_tavgp025/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to temperature at 1.4')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#for TempSnow
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolor(run_lon, run_lat, (run_tsnow15/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to TempSnow at 1.5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1,2,2)
plt.pcolor(run_lon, run_lat, (run_tsnow5/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to TempSnow at 5.0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

#for TempMelt
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolor(run_lon, run_lat, (run_tmelt15/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to TempMelt at 1.5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.subplot(1,2,2)
plt.pcolor(run_lon, run_lat, (run_tmelt5/run_main)*100, cmap='coolwarm')
plt.colorbar()
plt.title('Percentage change in average runoff due to TempMelt at 5.0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')


plt.show()

# %%
#plot map the percentage change in runoff for the first month with base as 1.0 for precipitation at 0.6 and 1.4 side by side horizontally
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolormesh(run_lon, run_lat, (run_precn025[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to precipitation at 0.6')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.subplot(1,2,2)
plt.pcolormesh(run_lon, run_lat, (run_precp025[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to precipitation at 1.4')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

#plot map the percentage change in runoff for the first month with base as 1.0 for temperature at 0.6 and 1.4 side by side horizontally
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolormesh(run_lon, run_lat, (run_tavgn025[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to temperature at 0.6')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.subplot(1,2,2)
plt.pcolormesh(run_lon, run_lat, (run_tavgp025[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to temperature at 1.4')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

#plot map the percentage change in runoff for the first month with base as 1.0 for TempSnow at 1.5 and 5.0 side by side horizontally
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolormesh(run_lon, run_lat, (run_tsnow15[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to TempSnow at 1.5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.subplot(1,2,2)
plt.pcolormesh(run_lon, run_lat, (run_tsnow5[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to TempSnow at 5.0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

#plot map the percentage change in runoff for the first month with base as 1.0 for TempMelt at 1.5 and 5.0 side by side horizontally
plt.figure(figsize=(20,10))
plt.subplot(1,2,1)
plt.pcolormesh(run_lon, run_lat, (run_tmelt15[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to TempMelt at 1.5')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.subplot(1,2,2)
plt.pcolormesh(run_lon, run_lat, (run_tmelt5[0]-run_main[0])/run_main[0]*100)
plt.colorbar()
plt.title('Percentage change in runoff due to TempMelt at 5.0')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
